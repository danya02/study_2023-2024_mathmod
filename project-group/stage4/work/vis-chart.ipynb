# %%
using Plots
using JSON

# %%
data = JSON.parsefile("./solarium/demo2/2-fullenergies.json")
# Out:
# Dict{String, Any} with 3 entries:
#   "kinetic"          => Any[1.58828e8, 3.85037e16, 3.85037e16, 3.85037e16, 3.86…
#   "potential"        => Any[-1.58471e7, -1.01198e7, -9.57021e6, -9.63823e6, -1.…
#   "active_particles" => Any[10000, 10000, 9671, 9446, 9182, 8907, 8611, 8343, 8…

# %%
plot([data["potential"], data["kinetic"]])

# %%
plot(data["active_particles"])
