# %%
using Plots
using JSON

# %%
data = JSON.parsefile("./solarium/demo2/2-fullenergies.json")
# Out:
# Dict{String, Any} with 3 entries:
#   "kinetic"          => Any[1.5547e8, 2.06849e12, 2.06848e12, 2.06848e12, 2.068…
#   "potential"        => Any[-1.39777e9, -1.39189e9, -1.39098e9, -1.38988e9, -1.…
#   "active_particles" => Any[10000, 10000, 9670, 9450, 9167, 8879, 8626, 8337, 8…

# %%
plot([data["potential"], data["kinetic"]])

# %%
plot(data["active_particles"])
